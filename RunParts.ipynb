# %%
import matplotlib
matplotlib.use("nbagg")
import math
import numpy as np
import matplotlib.pyplot as plt
import cv2
import re, os, glob, pickle, shutil,sys
from random import randint
import time
from shutil import *

os.environ["THEANO_FLAGS"] = "mode=FAST_RUN,device=gpu3,floatX=float32"
import theano
import theano.tensor as T
from theano import *
theano.__version__
from theano.sandbox.cuda import dnn

import pandas as pd
from theano import tensor as T
from theano.sandbox.rng_mrg import MRG_RandomStreams as RandomStreams


from theano.compile.nanguardmode import NanGuardMode

#from pom_funcs import *
from pom_room import POM_room
from pom_evaluator import POM_evaluator
import POMLayers1
from EM_funcs import *
import ZtoY
config.allow_gc =False

# %load_ext autoreload
# %autoreload 2


import Config
# Out:
# Using gpu device 3: GeForce GTX TITAN Z (CNMeM is disabled, cuDNN 5110)
# /home/baque/.local/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py:600: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)

# %%
from GaussianNet import gaussianNet
parts_predictor = gaussianNet()
parts_predictor.run_inference(bg_pretrained = True,regression_pretrained = True,verbose = True)
# Out:
# /home/baque/.local/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:6: UserWarning: downsample module has been moved to the theano.tensor.signal.pool module.
#   "downsample module has been moved to the theano.tensor.signal.pool module.")
# GaussianNet.py:147: UserWarning: theano.function was asked to create a function computing outputs given certain inputs, but the provided input variable at index 2 is not part of the computational graph needed to compute the outputs: dropout.
# To make this warning into an error, you can pass the parameter on_unused_input='raise' to theano.function. To disable it completely, use on_unused_input='ignore'.
#   updates=updates_bg, allow_input_downcast=True,on_unused_input='warn')
# GaussianNet.py:156: UserWarning: theano.function was asked to create a function computing outputs given certain inputs, but the provided input variable at index 0 is not part of the computational graph needed to compute the outputs: X.
# To make this warning into an error, you can pass the parameter on_unused_input='raise' to theano.function. To disable it completely, use on_unused_input='ignore'.
#   on_unused_input='warn')
# GaussianNet.py:156: UserWarning: theano.function was asked to create a function computing outputs given certain inputs, but the provided input variable at index 1 is not part of the computational graph needed to compute the outputs: Y_in.
# To make this warning into an error, you can pass the parameter on_unused_input='raise' to theano.function. To disable it completely, use on_unused_input='ignore'.
#   on_unused_input='warn')
# GaussianNet.py:156: UserWarning: theano.function was asked to create a function computing outputs given certain inputs, but the provided input variable at index 2 is not part of the computational graph needed to compute the outputs: dropout.
# To make this warning into an error, you can pass the parameter on_unused_input='raise' to theano.function. To disable it completely, use on_unused_input='ignore'.
#   on_unused_input='warn')
# Running inference for cam 0, fid 2000:
# Running inference for cam 0, fid 2005:
# Running inference for cam 0, fid 2010:
# Running inference for cam 0, fid 2015:
# Running inference for cam 0, fid 2020:
# Running inference for cam 0, fid 2025:
# Running inference for cam 0, fid 2030:
# Running inference for cam 0, fid 2035:
# Running inference for cam 0, fid 2040:
# Running inference for cam 0, fid 2045:
# Running inference for cam 0, fid 2050:
# Running inference for cam 0, fid 2055:
# Running inference for cam 0, fid 2060:
# Running inference for cam 0, fid 2065:
# Running inference for cam 0, fid 2070:
# Running inference for cam 0, fid 2075:
# Running inference for cam 0, fid 2080:
# Running inference for cam 0, fid 2085:
# Running inference for cam 0, fid 2090:
# Running inference for cam 0, fid 2095:
# Running inference for cam 0, fid 2100:
# Running inference for cam 0, fid 2105:
# Running inference for cam 0, fid 2110:
# Running inference for cam 0, fid 2115:
# Running inference for cam 0, fid 2120:
# Running inference for cam 0, fid 2125:
# Running inference for cam 0, fid 2130:
# Running inference for cam 0, fid 2135:
# Running inference for cam 0, fid 2140:
# Running inference for cam 0, fid 2145:
# Running inference for cam 0, fid 2150:
# Running inference for cam 0, fid 2155:
# Running inference for cam 0, fid 2160:
# Running inference for cam 0, fid 2165:
# Running inference for cam 0, fid 2170:
# Running inference for cam 0, fid 2175:
# Running inference for cam 0, fid 2180:
# Running inference for cam 0, fid 2185:
# Running inference for cam 0, fid 2190:
# Running inference for cam 0, fid 2195:
# Running inference for cam 0, fid 2200:
# Running inference for cam 0, fid 2205:
# Running inference for cam 0, fid 2210:
# Running inference for cam 0, fid 2215:
# Running inference for cam 0, fid 2220:
# Running inference for cam 0, fid 2225:
# Running inference for cam 0, fid 2230:
# Running inference for cam 0, fid 2235:
# Running inference for cam 0, fid 2240:
# Running inference for cam 0, fid 2245:
# Running inference for cam 0, fid 2250:
# Running inference for cam 0, fid 2255:
# Running inference for cam 0, fid 2260:
# Running inference for cam 0, fid 2265:
# Running inference for cam 0, fid 2270:
# Running inference for cam 0, fid 2275:
# Running inference for cam 0, fid 2280:
# Running inference for cam 0, fid 2285:
# Running inference for cam 0, fid 2290:
# Running inference for cam 0, fid 2295:
# Running inference for cam 0, fid 2300:
# Running inference for cam 0, fid 2305:
# Running inference for cam 0, fid 2310:
# Running inference for cam 0, fid 2315:
# Running inference for cam 0, fid 2320:
# Running inference for cam 0, fid 2325:
# Running inference for cam 0, fid 2330:
# Running inference for cam 0, fid 2335:
# Running inference for cam 0, fid 2340:
# Running inference for cam 0, fid 2345:
# Running inference for cam 0, fid 2350:
# Running inference for cam 0, fid 2355:
# Running inference for cam 0, fid 2360:
# Running inference for cam 0, fid 2365:
# Running inference for cam 0, fid 2370:
# Running inference for cam 0, fid 2375:
# Running inference for cam 0, fid 2380:
# Running inference for cam 0, fid 2385:
# Running inference for cam 0, fid 2390:
# Running inference for cam 0, fid 2395:
# Running inference for cam 0, fid 2400:
# Running inference for cam 0, fid 2405:
# Running inference for cam 0, fid 2410:
# Running inference for cam 0, fid 2415:
# Running inference for cam 0, fid 2420:
# Running inference for cam 0, fid 2425:
# Running inference for cam 0, fid 2430:
# Running inference for cam 0, fid 2435:
# Running inference for cam 0, fid 2440:
# Running inference for cam 0, fid 2445:
# Running inference for cam 0, fid 2450:
# Running inference for cam 0, fid 2455:
# Running inference for cam 0, fid 2460:
# Running inference for cam 0, fid 2465:
# Running inference for cam 0, fid 2470:
# Running inference for cam 0, fid 2475:
# Running inference for cam 0, fid 2480:
# Running inference for cam 0, fid 2485:
# Running inference for cam 0, fid 2490:
# Running inference for cam 0, fid 2495:
# Running inference for cam 0, fid 2500:
# Running inference for cam 0, fid 2505:
# Running inference for cam 0, fid 2510:
# Running inference for cam 0, fid 2515:
# Running inference for cam 0, fid 2520:
# Running inference for cam 0, fid 2525:
# Running inference for cam 0, fid 2530:
# Running inference for cam 0, fid 2535:
# Running inference for cam 0, fid 2540:
# Running inference for cam 0, fid 2545:
# Running inference for cam 0, fid 2550:
# Running inference for cam 0, fid 2555:
# Running inference for cam 0, fid 2560:
# Running inference for cam 0, fid 2565:
# Running inference for cam 0, fid 2570:
# Running inference for cam 0, fid 2575:
# Running inference for cam 0, fid 2580:
# Running inference for cam 0, fid 2585:
# Running inference for cam 0, fid 2590:
# Running inference for cam 0, fid 2595:
# Running inference for cam 0, fid 2600:
# Running inference for cam 0, fid 2605:
# Running inference for cam 0, fid 2610:
# Running inference for cam 0, fid 2615:
# Running inference for cam 0, fid 2620:
# Running inference for cam 0, fid 2625:
# Running inference for cam 0, fid 2630:
# Running inference for cam 0, fid 2635:
# Running inference for cam 0, fid 2640:
# Running inference for cam 0, fid 2645:
# Running inference for cam 0, fid 2650:
# Running inference for cam 0, fid 2655:
# Running inference for cam 0, fid 2660:
# Running inference for cam 0, fid 2665:
# Running inference for cam 0, fid 2670:
# Running inference for cam 0, fid 2675:
# Running inference for cam 0, fid 2680:
# Running inference for cam 0, fid 2685:
# Running inference for cam 0, fid 2690:
# Running inference for cam 0, fid 2695:
# Running inference for cam 0, fid 2700:
# Running inference for cam 0, fid 2705:
# Running inference for cam 0, fid 2710:
# Running inference for cam 0, fid 2715:
# Running inference for cam 0, fid 2720:
# Running inference for cam 0, fid 2725:
# Running inference for cam 0, fid 2730:
# Running inference for cam 0, fid 2735:
# Running inference for cam 0, fid 2740:
# Running inference for cam 0, fid 2745:
# Running inference for cam 0, fid 2750:
# Running inference for cam 0, fid 2755:
# Running inference for cam 0, fid 2760:
# Running inference for cam 0, fid 2765:
# Running inference for cam 0, fid 2770:
# Running inference for cam 0, fid 2775:
# Running inference for cam 0, fid 2780:
# Running inference for cam 0, fid 2785:
# Running inference for cam 0, fid 2790:
# Running inference for cam 0, fid 2795:
# Running inference for cam 0, fid 2800:
# Running inference for cam 0, fid 2805:
# Running inference for cam 0, fid 2810:
# Running inference for cam 0, fid 2815:
# Running inference for cam 0, fid 2820:
# Running inference for cam 0, fid 2825:
# Running inference for cam 0, fid 2830:
# Running inference for cam 0, fid 2835:
# Running inference for cam 0, fid 2840:
# Running inference for cam 0, fid 2845:
# Running inference for cam 0, fid 2850:
# Running inference for cam 0, fid 2855:
# Running inference for cam 0, fid 2860:
# Running inference for cam 0, fid 2865:
# Running inference for cam 0, fid 2870:
# Running inference for cam 0, fid 2875:
# Running inference for cam 0, fid 2880:
# Running inference for cam 0, fid 2885:
# Running inference for cam 0, fid 2890:
# Running inference for cam 0, fid 2895:
# Running inference for cam 0, fid 2900:
# Running inference for cam 0, fid 2905:
# Running inference for cam 0, fid 2910:
# Running inference for cam 0, fid 2915:
# Running inference for cam 0, fid 2920:
# Running inference for cam 0, fid 2925:
# Running inference for cam 0, fid 2930:
# Running inference for cam 0, fid 2935:
# Running inference for cam 0, fid 2940:
# Running inference for cam 0, fid 2945:
# Running inference for cam 0, fid 2950:
# Running inference for cam 0, fid 2955:
# Running inference for cam 0, fid 2960:
# Running inference for cam 0, fid 2965:
# Running inference for cam 0, fid 2970:
# Running inference for cam 0, fid 2975:
# Running inference for cam 0, fid 2980:
# Running inference for cam 0, fid 2985:
# Running inference for cam 0, fid 2990:
# Running inference for cam 0, fid 2995:
# Running inference for cam 0, fid 3000:
# Running inference for cam 0, fid 3005:
# Running inference for cam 0, fid 3010:
# Running inference for cam 0, fid 3015:
# Running inference for cam 0, fid 3020:
# Running inference for cam 0, fid 3025:
# Running inference for cam 0, fid 3030:
# Running inference for cam 0, fid 3035:
# Running inference for cam 0, fid 3040:
# Running inference for cam 0, fid 3045:
# Running inference for cam 0, fid 3050:
# Running inference for cam 0, fid 3055:
# Running inference for cam 0, fid 3060:
# Running inference for cam 0, fid 3065:
# Running inference for cam 0, fid 3070:
# Running inference for cam 0, fid 3075:
# Running inference for cam 0, fid 3080:
# Running inference for cam 0, fid 3085:
# Running inference for cam 0, fid 3090:
# Running inference for cam 0, fid 3095:
# Running inference for cam 0, fid 3100:
# Running inference for cam 0, fid 3105:
# Running inference for cam 0, fid 3110:
# Running inference for cam 0, fid 3115:
# Running inference for cam 0, fid 3120:
# Running inference for cam 0, fid 3125:
# Running inference for cam 0, fid 3130:
# Running inference for cam 0, fid 3135:
# Running inference for cam 0, fid 3140:
# Running inference for cam 0, fid 3145:
# Running inference for cam 0, fid 3150:
# Running inference for cam 0, fid 3155:
# Running inference for cam 0, fid 3160:
# Running inference for cam 0, fid 3165:
# Running inference for cam 0, fid 3170:
# Running inference for cam 0, fid 3175:
# Running inference for cam 0, fid 3180:
# Running inference for cam 0, fid 3185:
# Running inference for cam 0, fid 3190:
# Running inference for cam 0, fid 3195:
# Running inference for cam 0, fid 3200:
# Running inference for cam 0, fid 3205:
# Running inference for cam 0, fid 3210:
# Running inference for cam 0, fid 3215:
# Running inference for cam 0, fid 3220:
# Running inference for cam 0, fid 3225:
# Running inference for cam 0, fid 3230:
# Running inference for cam 0, fid 3235:
# Running inference for cam 0, fid 3240:
# Running inference for cam 0, fid 3245:
# Running inference for cam 0, fid 3250:
# Running inference for cam 0, fid 3255:
# Running inference for cam 0, fid 3260:
# Running inference for cam 0, fid 3265:
# Running inference for cam 0, fid 3270:
# Running inference for cam 0, fid 3275:
# Running inference for cam 0, fid 3280:
# Running inference for cam 0, fid 3285:
# Running inference for cam 0, fid 3290:
# Running inference for cam 0, fid 3295:
# Running inference for cam 0, fid 3300:
# Running inference for cam 0, fid 3305:
# Running inference for cam 0, fid 3310:
# Running inference for cam 0, fid 3315:
# Running inference for cam 0, fid 3320:
# Running inference for cam 0, fid 3325:
# Running inference for cam 0, fid 3330:
# Running inference for cam 0, fid 3335:
# Running inference for cam 0, fid 3340:
# Running inference for cam 0, fid 3345:
# Running inference for cam 0, fid 3350:
# Running inference for cam 0, fid 3355:
# Running inference for cam 0, fid 3360:
# Running inference for cam 0, fid 3365:
# Running inference for cam 0, fid 3370:
# Running inference for cam 0, fid 3375:
# Running inference for cam 0, fid 3380:
# Running inference for cam 0, fid 3385:
# Running inference for cam 0, fid 3390:
# Running inference for cam 0, fid 3395:
# Running inference for cam 0, fid 3400:
# Running inference for cam 0, fid 3405:
# Running inference for cam 0, fid 3410:
# Running inference for cam 0, fid 3415:
# Running inference for cam 0, fid 3420:
# Running inference for cam 0, fid 3425:
# Running inference for cam 0, fid 3430:
# Running inference for cam 0, fid 3435:
# Running inference for cam 0, fid 3440:
# Running inference for cam 0, fid 3445:
# Running inference for cam 0, fid 3450:
# Running inference for cam 0, fid 3455:
# Running inference for cam 0, fid 3460:
# Running inference for cam 0, fid 3465:
# Running inference for cam 0, fid 3470:
# Running inference for cam 0, fid 3475:
# Running inference for cam 0, fid 3480:
# Running inference for cam 0, fid 3485:
# Running inference for cam 0, fid 3490:
# Running inference for cam 0, fid 3495:
# Running inference for cam 0, fid 3500:
# Running inference for cam 0, fid 3505:
# Running inference for cam 0, fid 3510:
# Running inference for cam 0, fid 3515:
# Running inference for cam 0, fid 3520:
# Running inference for cam 0, fid 3525:
# Running inference for cam 0, fid 3530:
# Running inference for cam 0, fid 3535:
# Running inference for cam 0, fid 3540:
# Running inference for cam 0, fid 3545:
# Running inference for cam 0, fid 3550:
# Running inference for cam 0, fid 3555:
# Running inference for cam 0, fid 3560:
# Running inference for cam 0, fid 3565:
# Running inference for cam 0, fid 3570:
# Running inference for cam 0, fid 3575:
# Running inference for cam 0, fid 3580:
# Running inference for cam 0, fid 3585:
# Running inference for cam 0, fid 3590:
# Running inference for cam 0, fid 3595:
# Running inference for cam 0, fid 3600:
# Running inference for cam 0, fid 3605:
# Running inference for cam 0, fid 3610:
# Running inference for cam 0, fid 3615:
# Running inference for cam 0, fid 3620:
# Running inference for cam 0, fid 3625:
# Running inference for cam 0, fid 3630:
# Running inference for cam 0, fid 3635:
# Running inference for cam 0, fid 3640:
# Running inference for cam 0, fid 3645:
# Running inference for cam 0, fid 3650:
# Running inference for cam 0, fid 3655:
# Running inference for cam 0, fid 3660:
# Running inference for cam 0, fid 3665:
# Running inference for cam 0, fid 3670:
# Running inference for cam 0, fid 3675:
# Running inference for cam 0, fid 3680:
# Running inference for cam 0, fid 3685:
# Running inference for cam 0, fid 3690:
# Running inference for cam 0, fid 3695:
# Running inference for cam 0, fid 3700:
# Running inference for cam 0, fid 3705:
# Running inference for cam 0, fid 3710:
# Running inference for cam 0, fid 3715:
# Running inference for cam 0, fid 3720:
# Running inference for cam 0, fid 3725:
# Running inference for cam 0, fid 3730:
# Running inference for cam 0, fid 3735:
# Running inference for cam 0, fid 3740:
# Running inference for cam 0, fid 3745:
# Running inference for cam 0, fid 3750:
# Running inference for cam 0, fid 3755:
# Running inference for cam 0, fid 3760:
# Running inference for cam 0, fid 3765:
# Running inference for cam 0, fid 3770:
# Running inference for cam 0, fid 3775:
# Running inference for cam 0, fid 3780:
# Running inference for cam 0, fid 3785:
# Running inference for cam 0, fid 3790:
# Running inference for cam 0, fid 3795:
# Running inference for cam 0, fid 3800:
# Running inference for cam 0, fid 3805:
# Running inference for cam 0, fid 3810:
# Running inference for cam 0, fid 3815:
# Running inference for cam 0, fid 3820:
# Running inference for cam 0, fid 3825:
# Running inference for cam 0, fid 3830:
# Running inference for cam 0, fid 3835:
# Running inference for cam 0, fid 3840:
# Running inference for cam 0, fid 3845:
# Running inference for cam 0, fid 3850:
# Running inference for cam 0, fid 3855:
# Running inference for cam 0, fid 3860:
# Running inference for cam 0, fid 3865:
# Running inference for cam 0, fid 3870:
# Running inference for cam 0, fid 3875:
# Running inference for cam 0, fid 3880:
# Running inference for cam 0, fid 3885:
# Running inference for cam 0, fid 3890:
# Running inference for cam 0, fid 3895:
# Running inference for cam 0, fid 3900:
# Running inference for cam 0, fid 3905:
# Running inference for cam 0, fid 3910:
# Running inference for cam 0, fid 3915:
# Running inference for cam 0, fid 3920:
# Running inference for cam 0, fid 3925:
# Running inference for cam 0, fid 3930:
# Running inference for cam 0, fid 3935:
# Running inference for cam 0, fid 3940:
# Running inference for cam 0, fid 3945:
# Running inference for cam 0, fid 3950:
# Running inference for cam 0, fid 3955:
# Running inference for cam 0, fid 3960:
# Running inference for cam 0, fid 3965:
# Running inference for cam 0, fid 3970:
# Running inference for cam 0, fid 3975:
# Running inference for cam 0, fid 3980:
# Running inference for cam 0, fid 3985:
# Running inference for cam 0, fid 3990:
# Running inference for cam 0, fid 3995:
# Running inference for cam 1, fid 2000:
# Running inference for cam 1, fid 2005:
# Running inference for cam 1, fid 2010:
# Running inference for cam 1, fid 2015:
# Running inference for cam 1, fid 2020:
# Running inference for cam 1, fid 2025:
# Running inference for cam 1, fid 2030:
# Running inference for cam 1, fid 2035:
# Running inference for cam 1, fid 2040:
# Running inference for cam 1, fid 2045:
# Running inference for cam 1, fid 2050:
# Running inference for cam 1, fid 2055:
# Running inference for cam 1, fid 2060:
# Running inference for cam 1, fid 2065:
# Running inference for cam 1, fid 2070:
# Running inference for cam 1, fid 2075:
# Running inference for cam 1, fid 2080:
# Running inference for cam 1, fid 2085:
# Running inference for cam 1, fid 2090:
# Running inference for cam 1, fid 2095:
# Running inference for cam 1, fid 2100:
# Running inference for cam 1, fid 2105:
# Running inference for cam 1, fid 2110:
# Running inference for cam 1, fid 2115:
# Running inference for cam 1, fid 2120:
# Running inference for cam 1, fid 2125:
# Running inference for cam 1, fid 2130:
# Running inference for cam 1, fid 2135:
# Running inference for cam 1, fid 2140:
# Running inference for cam 1, fid 2145:
# Running inference for cam 1, fid 2150:
# Running inference for cam 1, fid 2155:
# Running inference for cam 1, fid 2160:
# Running inference for cam 1, fid 2165:
# Running inference for cam 1, fid 2170:
# Running inference for cam 1, fid 2175:
# Running inference for cam 1, fid 2180:
# Running inference for cam 1, fid 2185:
# Running inference for cam 1, fid 2190:
# Running inference for cam 1, fid 2195:
# Running inference for cam 1, fid 2200:
# Running inference for cam 1, fid 2205:
# Running inference for cam 1, fid 2210:
# Running inference for cam 1, fid 2215:
# Running inference for cam 1, fid 2220:
# Running inference for cam 1, fid 2225:
# Running inference for cam 1, fid 2230:
# Running inference for cam 1, fid 2235:
# Running inference for cam 1, fid 2240:
# Running inference for cam 1, fid 2245:
# Running inference for cam 1, fid 2250:
# Running inference for cam 1, fid 2255:
# Running inference for cam 1, fid 2260:
# Running inference for cam 1, fid 2265:
# Running inference for cam 1, fid 2270:
# Running inference for cam 1, fid 2275:
# Running inference for cam 1, fid 2280:
# Running inference for cam 1, fid 2285:
# Running inference for cam 1, fid 2290:
# Running inference for cam 1, fid 2295:
# Running inference for cam 1, fid 2300:
# Running inference for cam 1, fid 2305:
# Running inference for cam 1, fid 2310:
# Running inference for cam 1, fid 2315:
# Running inference for cam 1, fid 2320:
# Running inference for cam 1, fid 2325:
# Running inference for cam 1, fid 2330:
# Running inference for cam 1, fid 2335:
# Running inference for cam 1, fid 2340:
# Running inference for cam 1, fid 2345:
# Running inference for cam 1, fid 2350:
# Running inference for cam 1, fid 2355:
# Running inference for cam 1, fid 2360:
# Running inference for cam 1, fid 2365:
# Running inference for cam 1, fid 2370:
# Running inference for cam 1, fid 2375:
# Running inference for cam 1, fid 2380:
# Running inference for cam 1, fid 2385:
# Running inference for cam 1, fid 2390:
# Running inference for cam 1, fid 2395:
# Running inference for cam 1, fid 2400:
# Running inference for cam 1, fid 2405:
# Running inference for cam 1, fid 2410:
# Running inference for cam 1, fid 2415:
# Running inference for cam 1, fid 2420:
# Running inference for cam 1, fid 2425:
# Running inference for cam 1, fid 2430:
# Running inference for cam 1, fid 2435:
# Running inference for cam 1, fid 2440:
# Running inference for cam 1, fid 2445:
# Running inference for cam 1, fid 2450:
# Running inference for cam 1, fid 2455:
# Running inference for cam 1, fid 2460:
# Running inference for cam 1, fid 2465:
# Running inference for cam 1, fid 2470:
# Running inference for cam 1, fid 2475:
# Running inference for cam 1, fid 2480:
# Running inference for cam 1, fid 2485:
# Running inference for cam 1, fid 2490:
# Running inference for cam 1, fid 2495:
# Running inference for cam 1, fid 2500:
# Running inference for cam 1, fid 2505:
# Running inference for cam 1, fid 2510:
# Running inference for cam 1, fid 2515:
# Running inference for cam 1, fid 2520:
# Running inference for cam 1, fid 2525:
# Running inference for cam 1, fid 2530:
# Running inference for cam 1, fid 2535:
# Running inference for cam 1, fid 2540:
# Running inference for cam 1, fid 2545:
# Running inference for cam 1, fid 2550:
# Running inference for cam 1, fid 2555:
# Running inference for cam 1, fid 2560:
# Running inference for cam 1, fid 2565:
# Running inference for cam 1, fid 2570:
# Running inference for cam 1, fid 2575:
# Running inference for cam 1, fid 2580:
# Running inference for cam 1, fid 2585:
# Running inference for cam 1, fid 2590:
# Running inference for cam 1, fid 2595:
# Running inference for cam 1, fid 2600:
# Running inference for cam 1, fid 2605:
# Running inference for cam 1, fid 2610:
# Running inference for cam 1, fid 2615:
# Running inference for cam 1, fid 2620:
# Running inference for cam 1, fid 2625:
# Running inference for cam 1, fid 2630:
# Running inference for cam 1, fid 2635:
# Running inference for cam 1, fid 2640:
# Running inference for cam 1, fid 2645:
# Running inference for cam 1, fid 2650:
# Running inference for cam 1, fid 2655:
# Running inference for cam 1, fid 2660:
# Running inference for cam 1, fid 2665:
# Running inference for cam 1, fid 2670:
# Running inference for cam 1, fid 2675:
# Running inference for cam 1, fid 2680:
# Running inference for cam 1, fid 2685:
# Running inference for cam 1, fid 2690:
# Running inference for cam 1, fid 2695:
# Running inference for cam 1, fid 2700:
# Running inference for cam 1, fid 2705:
# Running inference for cam 1, fid 2710:
# Running inference for cam 1, fid 2715:
# Running inference for cam 1, fid 2720:
# Running inference for cam 1, fid 2725:
# Running inference for cam 1, fid 2730:
# Running inference for cam 1, fid 2735:
# Running inference for cam 1, fid 2740:
# Running inference for cam 1, fid 2745:
# Running inference for cam 1, fid 2750:
# Running inference for cam 1, fid 2755:
# Running inference for cam 1, fid 2760:
# Running inference for cam 1, fid 2765:
# Running inference for cam 1, fid 2770:
# Running inference for cam 1, fid 2775:
# Running inference for cam 1, fid 2780:
# Running inference for cam 1, fid 2785:
# Running inference for cam 1, fid 2790:
# Running inference for cam 1, fid 2795:
# Running inference for cam 1, fid 2800:
# Running inference for cam 1, fid 2805:
# Running inference for cam 1, fid 2810:
# Running inference for cam 1, fid 2815:
# Running inference for cam 1, fid 2820:
# Running inference for cam 1, fid 2825:
# Running inference for cam 1, fid 2830:
# Running inference for cam 1, fid 2835:
# Running inference for cam 1, fid 2840:
# Running inference for cam 1, fid 2845:
# Running inference for cam 1, fid 2850:
# Running inference for cam 1, fid 2855:
# Running inference for cam 1, fid 2860:
# Running inference for cam 1, fid 2865:
# Running inference for cam 1, fid 2870:
# Running inference for cam 1, fid 2875:
# Running inference for cam 1, fid 2880:
# Running inference for cam 1, fid 2885:
# Running inference for cam 1, fid 2890:
# Running inference for cam 1, fid 2895:
# Running inference for cam 1, fid 2900:
# Running inference for cam 1, fid 2905:
# Running inference for cam 1, fid 2910:
# Running inference for cam 1, fid 2915:
# Running inference for cam 1, fid 2920:
# Running inference for cam 1, fid 2925:
# Running inference for cam 1, fid 2930:
# Running inference for cam 1, fid 2935:
# Running inference for cam 1, fid 2940:
# Running inference for cam 1, fid 2945:
# Running inference for cam 1, fid 2950:
# Running inference for cam 1, fid 2955:
# Running inference for cam 1, fid 2960:
# Running inference for cam 1, fid 2965:
# Running inference for cam 1, fid 2970:
# Running inference for cam 1, fid 2975:
# Running inference for cam 1, fid 2980:
# Running inference for cam 1, fid 2985:
# Running inference for cam 1, fid 2990:
# Running inference for cam 1, fid 2995:
# Running inference for cam 1, fid 3000:
# Running inference for cam 1, fid 3005:
# Running inference for cam 1, fid 3010:
# Running inference for cam 1, fid 3015:
# Running inference for cam 1, fid 3020:
# Running inference for cam 1, fid 3025:
# Running inference for cam 1, fid 3030:
# Running inference for cam 1, fid 3035:
# Running inference for cam 1, fid 3040:
# Running inference for cam 1, fid 3045:
# Running inference for cam 1, fid 3050:
# Running inference for cam 1, fid 3055:
# Running inference for cam 1, fid 3060:
# Running inference for cam 1, fid 3065:
# Running inference for cam 1, fid 3070:
# Running inference for cam 1, fid 3075:
# Running inference for cam 1, fid 3080:
# Running inference for cam 1, fid 3085:
# Running inference for cam 1, fid 3090:
# Running inference for cam 1, fid 3095:
# Running inference for cam 1, fid 3100:
# Running inference for cam 1, fid 3105:
# Running inference for cam 1, fid 3110:
# Running inference for cam 1, fid 3115:
# Running inference for cam 1, fid 3120:
# Running inference for cam 1, fid 3125:
# Running inference for cam 1, fid 3130:
# Running inference for cam 1, fid 3135:
# Running inference for cam 1, fid 3140:
# Running inference for cam 1, fid 3145:
# Running inference for cam 1, fid 3150:
# Running inference for cam 1, fid 3155:
# Running inference for cam 1, fid 3160:
# Running inference for cam 1, fid 3165:
# Running inference for cam 1, fid 3170:
# Running inference for cam 1, fid 3175:
# Running inference for cam 1, fid 3180:
# Running inference for cam 1, fid 3185:
# Running inference for cam 1, fid 3190:
# Running inference for cam 1, fid 3195:
# Running inference for cam 1, fid 3200:
# Running inference for cam 1, fid 3205:
# Running inference for cam 1, fid 3210:
# Running inference for cam 1, fid 3215:
# Running inference for cam 1, fid 3220:
# Running inference for cam 1, fid 3225:
# Running inference for cam 1, fid 3230:
# Running inference for cam 1, fid 3235:
# Running inference for cam 1, fid 3240:
# Running inference for cam 1, fid 3245:
# Running inference for cam 1, fid 3250:
# Running inference for cam 1, fid 3255:
# Running inference for cam 1, fid 3260:
# Running inference for cam 1, fid 3265:
# Running inference for cam 1, fid 3270:
# Running inference for cam 1, fid 3275:
# Running inference for cam 1, fid 3280:
# Running inference for cam 1, fid 3285:
# Running inference for cam 1, fid 3290:
# Running inference for cam 1, fid 3295:
# Running inference for cam 1, fid 3300:
# Running inference for cam 1, fid 3305:
# Running inference for cam 1, fid 3310:
# Running inference for cam 1, fid 3315:
# Running inference for cam 1, fid 3320:
# Running inference for cam 1, fid 3325:
# Running inference for cam 1, fid 3330:
# Running inference for cam 1, fid 3335:
# Running inference for cam 1, fid 3340:
# Running inference for cam 1, fid 3345:
# Running inference for cam 1, fid 3350:
# Running inference for cam 1, fid 3355:
# Running inference for cam 1, fid 3360:
# Running inference for cam 1, fid 3365:
# Running inference for cam 1, fid 3370:
# Running inference for cam 1, fid 3375:
# Running inference for cam 1, fid 3380:
# Running inference for cam 1, fid 3385:
# Running inference for cam 1, fid 3390:
# Running inference for cam 1, fid 3395:
# Running inference for cam 1, fid 3400:
# Running inference for cam 1, fid 3405:
# Running inference for cam 1, fid 3410:
# Running inference for cam 1, fid 3415:
# Running inference for cam 1, fid 3420:
# Running inference for cam 1, fid 3425:
# Running inference for cam 1, fid 3430:
# Running inference for cam 1, fid 3435:
# Running inference for cam 1, fid 3440:
# Running inference for cam 1, fid 3445:
# Running inference for cam 1, fid 3450:
# Running inference for cam 1, fid 3455:
# Running inference for cam 1, fid 3460:
# Running inference for cam 1, fid 3465:
# Running inference for cam 1, fid 3470:
# Running inference for cam 1, fid 3475:
# Running inference for cam 1, fid 3480:
# Running inference for cam 1, fid 3485:
# Running inference for cam 1, fid 3490:
# Running inference for cam 1, fid 3495:
# Running inference for cam 1, fid 3500:
# Running inference for cam 1, fid 3505:
# Running inference for cam 1, fid 3510:
# Running inference for cam 1, fid 3515:
# Running inference for cam 1, fid 3520:
# Running inference for cam 1, fid 3525:
# Running inference for cam 1, fid 3530:
# Running inference for cam 1, fid 3535:
# Running inference for cam 1, fid 3540:
# Running inference for cam 1, fid 3545:
# Running inference for cam 1, fid 3550:
# Running inference for cam 1, fid 3555:
# Running inference for cam 1, fid 3560:
# Running inference for cam 1, fid 3565:
# Running inference for cam 1, fid 3570:
# Running inference for cam 1, fid 3575:
# Running inference for cam 1, fid 3580:
# Running inference for cam 1, fid 3585:
# Running inference for cam 1, fid 3590:
# Running inference for cam 1, fid 3595:
# Running inference for cam 1, fid 3600:
# Running inference for cam 1, fid 3605:
# Running inference for cam 1, fid 3610:
# Running inference for cam 1, fid 3615:
# Running inference for cam 1, fid 3620:
# Running inference for cam 1, fid 3625:
# Running inference for cam 1, fid 3630:
# Running inference for cam 1, fid 3635:
# Running inference for cam 1, fid 3640:
# Running inference for cam 1, fid 3645:
# Running inference for cam 1, fid 3650:
# Running inference for cam 1, fid 3655:
# Running inference for cam 1, fid 3660:
# Running inference for cam 1, fid 3665:
# Running inference for cam 1, fid 3670:
# Running inference for cam 1, fid 3675:
# Running inference for cam 1, fid 3680:
# Running inference for cam 1, fid 3685:
# Running inference for cam 1, fid 3690:
# Running inference for cam 1, fid 3695:
# Running inference for cam 1, fid 3700:
# Running inference for cam 1, fid 3705:
# Running inference for cam 1, fid 3710:
# Running inference for cam 1, fid 3715:
# Running inference for cam 1, fid 3720:
# Running inference for cam 1, fid 3725:
# Running inference for cam 1, fid 3730:
# Running inference for cam 1, fid 3735:
# Running inference for cam 1, fid 3740:
# Running inference for cam 1, fid 3745:
# Running inference for cam 1, fid 3750:
# Running inference for cam 1, fid 3755:
# Running inference for cam 1, fid 3760:
# Running inference for cam 1, fid 3765:
# Running inference for cam 1, fid 3770:
# Running inference for cam 1, fid 3775:
# Running inference for cam 1, fid 3780:
# Running inference for cam 1, fid 3785:
# Running inference for cam 1, fid 3790:
# Running inference for cam 1, fid 3795:
# Running inference for cam 1, fid 3800:
# Running inference for cam 1, fid 3805:
# Running inference for cam 1, fid 3810:
# Running inference for cam 1, fid 3815:
# Running inference for cam 1, fid 3820:
# Running inference for cam 1, fid 3825:
# Running inference for cam 1, fid 3830:
# Running inference for cam 1, fid 3835:
# Running inference for cam 1, fid 3840:
# Running inference for cam 1, fid 3845:
# Running inference for cam 1, fid 3850:
# Running inference for cam 1, fid 3855:
# Running inference for cam 1, fid 3860:
# Running inference for cam 1, fid 3865:
# Running inference for cam 1, fid 3870:
# Running inference for cam 1, fid 3875:
# Running inference for cam 1, fid 3880:
# Running inference for cam 1, fid 3885:
# Running inference for cam 1, fid 3890:
# Running inference for cam 1, fid 3895:
# Running inference for cam 1, fid 3900:
# Running inference for cam 1, fid 3905:
# Running inference for cam 1, fid 3910:
# Running inference for cam 1, fid 3915:
# Running inference for cam 1, fid 3920:
# Running inference for cam 1, fid 3925:
# Running inference for cam 1, fid 3930:
# Running inference for cam 1, fid 3935:
# Running inference for cam 1, fid 3940:
# Running inference for cam 1, fid 3945:
# Running inference for cam 1, fid 3950:
# Running inference for cam 1, fid 3955:
# Running inference for cam 1, fid 3960:
# Running inference for cam 1, fid 3965:
# Running inference for cam 1, fid 3970:
# Running inference for cam 1, fid 3975:
# Running inference for cam 1, fid 3980:
# Running inference for cam 1, fid 3985:
# Running inference for cam 1, fid 3990:
# Running inference for cam 1, fid 3995:
# Running inference for cam 2, fid 2000:
# Running inference for cam 2, fid 2005:
# Running inference for cam 2, fid 2010:
# Running inference for cam 2, fid 2015:
# Running inference for cam 2, fid 2020:
# Running inference for cam 2, fid 2025:
# Running inference for cam 2, fid 2030:
# Running inference for cam 2, fid 2035:
# Running inference for cam 2, fid 2040:
# Running inference for cam 2, fid 2045:
# Running inference for cam 2, fid 2050:
# Running inference for cam 2, fid 2055:
# Running inference for cam 2, fid 2060:
# Running inference for cam 2, fid 2065:
# Running inference for cam 2, fid 2070:
# Running inference for cam 2, fid 2075:
# Running inference for cam 2, fid 2080:
# Running inference for cam 2, fid 2085:
# Running inference for cam 2, fid 2090:
# Running inference for cam 2, fid 2095:
# Running inference for cam 2, fid 2100:
# Running inference for cam 2, fid 2105:
# Running inference for cam 2, fid 2110:
# Running inference for cam 2, fid 2115:
# Running inference for cam 2, fid 2120:
# Running inference for cam 2, fid 2125:
# Running inference for cam 2, fid 2130:
# Running inference for cam 2, fid 2135:
# Running inference for cam 2, fid 2140:
# Running inference for cam 2, fid 2145:
# Running inference for cam 2, fid 2150:
# Running inference for cam 2, fid 2155:
# Running inference for cam 2, fid 2160:
# Running inference for cam 2, fid 2165:
# Running inference for cam 2, fid 2170:
# Running inference for cam 2, fid 2175:
# Running inference for cam 2, fid 2180:
# Running inference for cam 2, fid 2185:
# Running inference for cam 2, fid 2190:
# Running inference for cam 2, fid 2195:
# Running inference for cam 2, fid 2200:
# Running inference for cam 2, fid 2205:
# Running inference for cam 2, fid 2210:
# Running inference for cam 2, fid 2215:
# Running inference for cam 2, fid 2220:
# Running inference for cam 2, fid 2225:
# Running inference for cam 2, fid 2230:
# Running inference for cam 2, fid 2235:
# Running inference for cam 2, fid 2240:
# Running inference for cam 2, fid 2245:
# Running inference for cam 2, fid 2250:
# Running inference for cam 2, fid 2255:
# Running inference for cam 2, fid 2260:
# Running inference for cam 2, fid 2265:
# Running inference for cam 2, fid 2270:
# Running inference for cam 2, fid 2275:
# Running inference for cam 2, fid 2280:
# Running inference for cam 2, fid 2285:
# Running inference for cam 2, fid 2290:
# Running inference for cam 2, fid 2295:
# Running inference for cam 2, fid 2300:
# Running inference for cam 2, fid 2305:
# Running inference for cam 2, fid 2310:
# Running inference for cam 2, fid 2315:
# Running inference for cam 2, fid 2320:
# Running inference for cam 2, fid 2325:
# Running inference for cam 2, fid 2330:
# Running inference for cam 2, fid 2335:
# Running inference for cam 2, fid 2340:
# Running inference for cam 2, fid 2345:
# Running inference for cam 2, fid 2350:
# Running inference for cam 2, fid 2355:
# Running inference for cam 2, fid 2360:
# Running inference for cam 2, fid 2365:
# Running inference for cam 2, fid 2370:
# Running inference for cam 2, fid 2375:
# Running inference for cam 2, fid 2380:
# Running inference for cam 2, fid 2385:
# Running inference for cam 2, fid 2390:
# Running inference for cam 2, fid 2395:
# Running inference for cam 2, fid 2400:
# Running inference for cam 2, fid 2405:
# Running inference for cam 2, fid 2410:
# Running inference for cam 2, fid 2415:
# Running inference for cam 2, fid 2420:
# Running inference for cam 2, fid 2425:
# Running inference for cam 2, fid 2430:
# Running inference for cam 2, fid 2435:
# Running inference for cam 2, fid 2440:
# Running inference for cam 2, fid 2445:
# Running inference for cam 2, fid 2450:
# Running inference for cam 2, fid 2455:
# Running inference for cam 2, fid 2460:
# Running inference for cam 2, fid 2465:
# Running inference for cam 2, fid 2470:
# Running inference for cam 2, fid 2475:
# Running inference for cam 2, fid 2480:
# Running inference for cam 2, fid 2485:
# Running inference for cam 2, fid 2490:
# Running inference for cam 2, fid 2495:
# Running inference for cam 2, fid 2500:
# Running inference for cam 2, fid 2505:
# Running inference for cam 2, fid 2510:
# Running inference for cam 2, fid 2515:
# Running inference for cam 2, fid 2520:
# Running inference for cam 2, fid 2525:
# Running inference for cam 2, fid 2530:
# Running inference for cam 2, fid 2535:
# Running inference for cam 2, fid 2540:
# Running inference for cam 2, fid 2545:
# Running inference for cam 2, fid 2550:
# Running inference for cam 2, fid 2555:
# Running inference for cam 2, fid 2560:
# Running inference for cam 2, fid 2565:
# Running inference for cam 2, fid 2570:
# Running inference for cam 2, fid 2575:
# Running inference for cam 2, fid 2580:
# Running inference for cam 2, fid 2585:
# Running inference for cam 2, fid 2590:
# Running inference for cam 2, fid 2595:
# Running inference for cam 2, fid 2600:
# Running inference for cam 2, fid 2605:
# Running inference for cam 2, fid 2610:
# Running inference for cam 2, fid 2615:
# Running inference for cam 2, fid 2620:
# Running inference for cam 2, fid 2625:
# Running inference for cam 2, fid 2630:
# Running inference for cam 2, fid 2635:
# Running inference for cam 2, fid 2640:
# Running inference for cam 2, fid 2645:
# Running inference for cam 2, fid 2650:
# Running inference for cam 2, fid 2655:
# Running inference for cam 2, fid 2660:
# Running inference for cam 2, fid 2665:
# Running inference for cam 2, fid 2670:
# Running inference for cam 2, fid 2675:
# Running inference for cam 2, fid 2680:
# Running inference for cam 2, fid 2685:
# Running inference for cam 2, fid 2690:
# Running inference for cam 2, fid 2695:
# Running inference for cam 2, fid 2700:
# Running inference for cam 2, fid 2705:
# Running inference for cam 2, fid 2710:
# Running inference for cam 2, fid 2715:
# Running inference for cam 2, fid 2720:
# Running inference for cam 2, fid 2725:
# Running inference for cam 2, fid 2730:
# Running inference for cam 2, fid 2735:
# Running inference for cam 2, fid 2740:
# Running inference for cam 2, fid 2745:
# Running inference for cam 2, fid 2750:
# Running inference for cam 2, fid 2755:
# Running inference for cam 2, fid 2760:
# Running inference for cam 2, fid 2765:
# Running inference for cam 2, fid 2770:
# Running inference for cam 2, fid 2775:
# Running inference for cam 2, fid 2780:
# Running inference for cam 2, fid 2785:
# Running inference for cam 2, fid 2790:
# Running inference for cam 2, fid 2795:
# Running inference for cam 2, fid 2800:
# Running inference for cam 2, fid 2805:
# Running inference for cam 2, fid 2810:
# Running inference for cam 2, fid 2815:
# Running inference for cam 2, fid 2820:
# Running inference for cam 2, fid 2825:
# Running inference for cam 2, fid 2830:
# Running inference for cam 2, fid 2835:
# Running inference for cam 2, fid 2840:
# Running inference for cam 2, fid 2845:
# Running inference for cam 2, fid 2850:
# Running inference for cam 2, fid 2855:
# Running inference for cam 2, fid 2860:
# Running inference for cam 2, fid 2865:
# Running inference for cam 2, fid 2870:
# Running inference for cam 2, fid 2875:
# Running inference for cam 2, fid 2880:
# Running inference for cam 2, fid 2885:
# Running inference for cam 2, fid 2890:
# Running inference for cam 2, fid 2895:
# Running inference for cam 2, fid 2900:
# Running inference for cam 2, fid 2905:
# Running inference for cam 2, fid 2910:
# Running inference for cam 2, fid 2915:
# Running inference for cam 2, fid 2920:
# Running inference for cam 2, fid 2925:
# Running inference for cam 2, fid 2930:
# Running inference for cam 2, fid 2935:
# Running inference for cam 2, fid 2940:
# Running inference for cam 2, fid 2945:
# Running inference for cam 2, fid 2950:
# Running inference for cam 2, fid 2955:
# Running inference for cam 2, fid 2960:
# Running inference for cam 2, fid 2965:
# Running inference for cam 2, fid 2970:
# Running inference for cam 2, fid 2975:
# Running inference for cam 2, fid 2980:
# Running inference for cam 2, fid 2985:
# Running inference for cam 2, fid 2990:
# Running inference for cam 2, fid 2995:
# Running inference for cam 2, fid 3000:
# Running inference for cam 2, fid 3005:
# Running inference for cam 2, fid 3010:
# Running inference for cam 2, fid 3015:
# Running inference for cam 2, fid 3020:
# Running inference for cam 2, fid 3025:
# Running inference for cam 2, fid 3030:
# Running inference for cam 2, fid 3035:
# Running inference for cam 2, fid 3040:
# Running inference for cam 2, fid 3045:
# Running inference for cam 2, fid 3050:
# Running inference for cam 2, fid 3055:
# Running inference for cam 2, fid 3060:
# Running inference for cam 2, fid 3065:
# Running inference for cam 2, fid 3070:
# Running inference for cam 2, fid 3075:
# Running inference for cam 2, fid 3080:
# Running inference for cam 2, fid 3085:
# Running inference for cam 2, fid 3090:
# Running inference for cam 2, fid 3095:
# Running inference for cam 2, fid 3100:
# Running inference for cam 2, fid 3105:
# Running inference for cam 2, fid 3110:
# Running inference for cam 2, fid 3115:
# Running inference for cam 2, fid 3120:
# Running inference for cam 2, fid 3125:
# Running inference for cam 2, fid 3130:
# Running inference for cam 2, fid 3135:
# Running inference for cam 2, fid 3140:
# Running inference for cam 2, fid 3145:
# Running inference for cam 2, fid 3150:
# Running inference for cam 2, fid 3155:
# Running inference for cam 2, fid 3160:
# Running inference for cam 2, fid 3165:
# Running inference for cam 2, fid 3170:
# Running inference for cam 2, fid 3175:
# Running inference for cam 2, fid 3180:
# Running inference for cam 2, fid 3185:
# Running inference for cam 2, fid 3190:
# Running inference for cam 2, fid 3195:
# Running inference for cam 2, fid 3200:
# Running inference for cam 2, fid 3205:
# Running inference for cam 2, fid 3210:
# Running inference for cam 2, fid 3215:
# Running inference for cam 2, fid 3220:
# Running inference for cam 2, fid 3225:
# Running inference for cam 2, fid 3230:
# Running inference for cam 2, fid 3235:
# Running inference for cam 2, fid 3240:
# Running inference for cam 2, fid 3245:
# Running inference for cam 2, fid 3250:
# Running inference for cam 2, fid 3255:
# Running inference for cam 2, fid 3260:
# Running inference for cam 2, fid 3265:
# Running inference for cam 2, fid 3270:
# Running inference for cam 2, fid 3275:
# Running inference for cam 2, fid 3280:
# Running inference for cam 2, fid 3285:
# Running inference for cam 2, fid 3290:
# Running inference for cam 2, fid 3295:
# Running inference for cam 2, fid 3300:
# Running inference for cam 2, fid 3305:
# Running inference for cam 2, fid 3310:
# Running inference for cam 2, fid 3315:
# Running inference for cam 2, fid 3320:
# Running inference for cam 2, fid 3325:
# Running inference for cam 2, fid 3330:
# Running inference for cam 2, fid 3335:
# Running inference for cam 2, fid 3340:
# Running inference for cam 2, fid 3345:
# Running inference for cam 2, fid 3350:
# Running inference for cam 2, fid 3355:
# Running inference for cam 2, fid 3360:
# Running inference for cam 2, fid 3365:
# Running inference for cam 2, fid 3370:
# Running inference for cam 2, fid 3375:
# Running inference for cam 2, fid 3380:
# Running inference for cam 2, fid 3385:
# Running inference for cam 2, fid 3390:
# Running inference for cam 2, fid 3395:
# Running inference for cam 2, fid 3400:
# Running inference for cam 2, fid 3405:
# Running inference for cam 2, fid 3410:
# Running inference for cam 2, fid 3415:
# Running inference for cam 2, fid 3420:
# Running inference for cam 2, fid 3425:
# Running inference for cam 2, fid 3430:
# Running inference for cam 2, fid 3435:
# Running inference for cam 2, fid 3440:
# Running inference for cam 2, fid 3445:
# Running inference for cam 2, fid 3450:
# Running inference for cam 2, fid 3455:
# Running inference for cam 2, fid 3460:
# Running inference for cam 2, fid 3465:
# Running inference for cam 2, fid 3470:
# Running inference for cam 2, fid 3475:
# Running inference for cam 2, fid 3480:
# Running inference for cam 2, fid 3485:
# Running inference for cam 2, fid 3490:
# Running inference for cam 2, fid 3495:
# Running inference for cam 2, fid 3500:
# Running inference for cam 2, fid 3505:
# Running inference for cam 2, fid 3510:
# Running inference for cam 2, fid 3515:
# Running inference for cam 2, fid 3520:
# Running inference for cam 2, fid 3525:
# Running inference for cam 2, fid 3530:
# Running inference for cam 2, fid 3535:
# Running inference for cam 2, fid 3540:
# Running inference for cam 2, fid 3545:
# Running inference for cam 2, fid 3550:
# Running inference for cam 2, fid 3555:
# Running inference for cam 2, fid 3560:
# Running inference for cam 2, fid 3565:
# Running inference for cam 2, fid 3570:
# Running inference for cam 2, fid 3575:
# Running inference for cam 2, fid 3580:
# Running inference for cam 2, fid 3585:
# Running inference for cam 2, fid 3590:
# Running inference for cam 2, fid 3595:
# Running inference for cam 2, fid 3600:
# Running inference for cam 2, fid 3605:
# Running inference for cam 2, fid 3610:
# Running inference for cam 2, fid 3615:
# Running inference for cam 2, fid 3620:
# Running inference for cam 2, fid 3625:
# Running inference for cam 2, fid 3630:
# Running inference for cam 2, fid 3635:
# Running inference for cam 2, fid 3640:
# Running inference for cam 2, fid 3645:
# Running inference for cam 2, fid 3650:
# Running inference for cam 2, fid 3655:
# Running inference for cam 2, fid 3660:
# Running inference for cam 2, fid 3665:
# Running inference for cam 2, fid 3670:
# Running inference for cam 2, fid 3675:
# Running inference for cam 2, fid 3680:
# Running inference for cam 2, fid 3685:
# Running inference for cam 2, fid 3690:
# Running inference for cam 2, fid 3695:
# Running inference for cam 2, fid 3700:
# Running inference for cam 2, fid 3705:
# Running inference for cam 2, fid 3710:
# Running inference for cam 2, fid 3715:
# Running inference for cam 2, fid 3720:
# Running inference for cam 2, fid 3725:
# Running inference for cam 2, fid 3730:
# Running inference for cam 2, fid 3735:
# Running inference for cam 2, fid 3740:
# Running inference for cam 2, fid 3745:
# Running inference for cam 2, fid 3750:
# Running inference for cam 2, fid 3755:
# Running inference for cam 2, fid 3760:
# Running inference for cam 2, fid 3765:
# Running inference for cam 2, fid 3770:
# Running inference for cam 2, fid 3775:
# Running inference for cam 2, fid 3780:
# Running inference for cam 2, fid 3785:
# Running inference for cam 2, fid 3790:
# Running inference for cam 2, fid 3795:
# Running inference for cam 2, fid 3800:
# Running inference for cam 2, fid 3805:
# Running inference for cam 2, fid 3810:
# Running inference for cam 2, fid 3815:
# Running inference for cam 2, fid 3820:
# Running inference for cam 2, fid 3825:
# Running inference for cam 2, fid 3830:
# Running inference for cam 2, fid 3835:
# Running inference for cam 2, fid 3840:
# Running inference for cam 2, fid 3845:
# Running inference for cam 2, fid 3850:
# Running inference for cam 2, fid 3855:
# Running inference for cam 2, fid 3860:
# Running inference for cam 2, fid 3865:
# Running inference for cam 2, fid 3870:
# Running inference for cam 2, fid 3875:
# Running inference for cam 2, fid 3880:
# Running inference for cam 2, fid 3885:
# Running inference for cam 2, fid 3890:
# ...
# Running inference for cam 2, fid 3950:
# Running inference for cam 2, fid 3955:
# Running inference for cam 2, fid 3960:
# Running inference for cam 2, fid 3965:
# Running inference for cam 2, fid 3970:
# Running inference for cam 2, fid 3975:
# Running inference for cam 2, fid 3980:
# Running inference for cam 2, fid 3985:
# Running inference for cam 2, fid 3990:
# Running inference for cam 2, fid 3995:
# Running inference for cam 3, fid 2000:
# Running inference for cam 3, fid 2005:
# Running inference for cam 3, fid 2010:
# Running inference for cam 3, fid 2015:
# Running inference for cam 3, fid 2020:
# Running inference for cam 3, fid 2025:
# Running inference for cam 3, fid 2030:
# Running inference for cam 3, fid 2035:
# Running inference for cam 3, fid 2040:
# Running inference for cam 3, fid 2045:
# Running inference for cam 3, fid 2050:
# Running inference for cam 3, fid 2055:
# Running inference for cam 3, fid 2060:
# Running inference for cam 3, fid 2065:
# Running inference for cam 3, fid 2070:
# Running inference for cam 3, fid 2075:
# Running inference for cam 3, fid 2080:
# Running inference for cam 3, fid 2085:
# Running inference for cam 3, fid 2090:
# Running inference for cam 3, fid 2095:
# Running inference for cam 3, fid 2100:
# Running inference for cam 3, fid 2105:
# Running inference for cam 3, fid 2110:
# Running inference for cam 3, fid 2115:
# Running inference for cam 3, fid 2120:
# Running inference for cam 3, fid 2125:
# Running inference for cam 3, fid 2130:
# Running inference for cam 3, fid 2135:
# Running inference for cam 3, fid 2140:
# Running inference for cam 3, fid 2145:
# Running inference for cam 3, fid 2150:
# Running inference for cam 3, fid 2155:
# Running inference for cam 3, fid 2160:
# Running inference for cam 3, fid 2165:
# Running inference for cam 3, fid 2170:
# Running inference for cam 3, fid 2175:
# Running inference for cam 3, fid 2180:
# Running inference for cam 3, fid 2185:
# Running inference for cam 3, fid 2190:
# Running inference for cam 3, fid 2195:
# Running inference for cam 3, fid 2200:
# Running inference for cam 3, fid 2205:
# Running inference for cam 3, fid 2210:
# Running inference for cam 3, fid 2215:
# Running inference for cam 3, fid 2220:
# Running inference for cam 3, fid 2225:
# Running inference for cam 3, fid 2230:
# Running inference for cam 3, fid 2235:
# Running inference for cam 3, fid 2240:
# Running inference for cam 3, fid 2245:
# Running inference for cam 3, fid 2250:
# Running inference for cam 3, fid 2255:
# Running inference for cam 3, fid 2260:
# Running inference for cam 3, fid 2265:
# Running inference for cam 3, fid 2270:
# Running inference for cam 3, fid 2275:
# Running inference for cam 3, fid 2280:
# Running inference for cam 3, fid 2285:
# Running inference for cam 3, fid 2290:
# Running inference for cam 3, fid 2295:
# Running inference for cam 3, fid 2300:
# Running inference for cam 3, fid 2305:
# Running inference for cam 3, fid 2310:
# Running inference for cam 3, fid 2315:
# Running inference for cam 3, fid 2320:
# Running inference for cam 3, fid 2325:
# Running inference for cam 3, fid 2330:
# Running inference for cam 3, fid 2335:
# Running inference for cam 3, fid 2340:
# Running inference for cam 3, fid 2345:
# Running inference for cam 3, fid 2350:
# Running inference for cam 3, fid 2355:
# Running inference for cam 3, fid 2360:
# Running inference for cam 3, fid 2365:
# Running inference for cam 3, fid 2370:
# Running inference for cam 3, fid 2375:
# Running inference for cam 3, fid 2380:
# Running inference for cam 3, fid 2385:
# Running inference for cam 3, fid 2390:
# Running inference for cam 3, fid 2395:
# Running inference for cam 3, fid 2400:
# Running inference for cam 3, fid 2405:
# Running inference for cam 3, fid 2410:
# Running inference for cam 3, fid 2415:
# Running inference for cam 3, fid 2420:
# Running inference for cam 3, fid 2425:
# Running inference for cam 3, fid 2430:
# Running inference for cam 3, fid 2435:
# Running inference for cam 3, fid 2440:
# Running inference for cam 3, fid 2445:
# Running inference for cam 3, fid 2450:
# Running inference for cam 3, fid 2455:
# Running inference for cam 3, fid 2460:
# Running inference for cam 3, fid 2465:
# Running inference for cam 3, fid 2470:
# Running inference for cam 3, fid 2475:
# Running inference for cam 3, fid 2480:
# Running inference for cam 3, fid 2485:
# Running inference for cam 3, fid 2490:
# Running inference for cam 3, fid 2495:
# Running inference for cam 3, fid 2500:
# Running inference for cam 3, fid 2505:
# Running inference for cam 3, fid 2510:
# Running inference for cam 3, fid 2515:
# Running inference for cam 3, fid 2520:
# Running inference for cam 3, fid 2525:
# Running inference for cam 3, fid 2530:
# Running inference for cam 3, fid 2535:
# Running inference for cam 3, fid 2540:
# Running inference for cam 3, fid 2545:
# Running inference for cam 3, fid 2550:
# Running inference for cam 3, fid 2555:
# Running inference for cam 3, fid 2560:
# Running inference for cam 3, fid 2565:
# Running inference for cam 3, fid 2570:
# Running inference for cam 3, fid 2575:
# Running inference for cam 3, fid 2580:
# Running inference for cam 3, fid 2585:
# Running inference for cam 3, fid 2590:
# Running inference for cam 3, fid 2595:
# Running inference for cam 3, fid 2600:
# Running inference for cam 3, fid 2605:
# Running inference for cam 3, fid 2610:
# Running inference for cam 3, fid 2615:
# Running inference for cam 3, fid 2620:
# Running inference for cam 3, fid 2625:
# Running inference for cam 3, fid 2630:
# Running inference for cam 3, fid 2635:
# Running inference for cam 3, fid 2640:
# Running inference for cam 3, fid 2645:
# Running inference for cam 3, fid 2650:
# Running inference for cam 3, fid 2655:
# Running inference for cam 3, fid 2660:
# Running inference for cam 3, fid 2665:
# Running inference for cam 3, fid 2670:
# Running inference for cam 3, fid 2675:
# Running inference for cam 3, fid 2680:
# Running inference for cam 3, fid 2685:
# Running inference for cam 3, fid 2690:
# Running inference for cam 3, fid 2695:
# Running inference for cam 3, fid 2700:
# Running inference for cam 3, fid 2705:
# Running inference for cam 3, fid 2710:
# Running inference for cam 3, fid 2715:
# Running inference for cam 3, fid 2720:
# Running inference for cam 3, fid 2725:
# Running inference for cam 3, fid 2730:
# Running inference for cam 3, fid 2735:
# Running inference for cam 3, fid 2740:
# Running inference for cam 3, fid 2745:
# Running inference for cam 3, fid 2750:
# Running inference for cam 3, fid 2755:
# Running inference for cam 3, fid 2760:
# Running inference for cam 3, fid 2765:
# Running inference for cam 3, fid 2770:
# Running inference for cam 3, fid 2775:
# Running inference for cam 3, fid 2780:
# Running inference for cam 3, fid 2785:
# Running inference for cam 3, fid 2790:
# Running inference for cam 3, fid 2795:
# Running inference for cam 3, fid 2800:
# Running inference for cam 3, fid 2805:
# Running inference for cam 3, fid 2810:
# Running inference for cam 3, fid 2815:
# Running inference for cam 3, fid 2820:
# Running inference for cam 3, fid 2825:
# Running inference for cam 3, fid 2830:
# Running inference for cam 3, fid 2835:
# Running inference for cam 3, fid 2840:
# Running inference for cam 3, fid 2845:
# Running inference for cam 3, fid 2850:
# Running inference for cam 3, fid 2855:
# Running inference for cam 3, fid 2860:
# Running inference for cam 3, fid 2865:
# Running inference for cam 3, fid 2870:
# Running inference for cam 3, fid 2875:
# Running inference for cam 3, fid 2880:
# Running inference for cam 3, fid 2885:
# Running inference for cam 3, fid 2890:
# Running inference for cam 3, fid 2895:
# Running inference for cam 3, fid 2900:
# Running inference for cam 3, fid 2905:
# Running inference for cam 3, fid 2910:
# Running inference for cam 3, fid 2915:
# Running inference for cam 3, fid 2920:
# Running inference for cam 3, fid 2925:
# Running inference for cam 3, fid 2930:
# Running inference for cam 3, fid 2935:
# Running inference for cam 3, fid 2940:
# Running inference for cam 3, fid 2945:
# Running inference for cam 3, fid 2950:
# Running inference for cam 3, fid 2955:
# Running inference for cam 3, fid 2960:
# Running inference for cam 3, fid 2965:
# Running inference for cam 3, fid 2970:
# Running inference for cam 3, fid 2975:
# Running inference for cam 3, fid 2980:
# Running inference for cam 3, fid 2985:
# Running inference for cam 3, fid 2990:
# Running inference for cam 3, fid 2995:
# Running inference for cam 3, fid 3000:
# Running inference for cam 3, fid 3005:
# Running inference for cam 3, fid 3010:
# Running inference for cam 3, fid 3015:
# Running inference for cam 3, fid 3020:
# Running inference for cam 3, fid 3025:
# Running inference for cam 3, fid 3030:
# Running inference for cam 3, fid 3035:
# Running inference for cam 3, fid 3040:
# Running inference for cam 3, fid 3045:
# Running inference for cam 3, fid 3050:
# Running inference for cam 3, fid 3055:
# Running inference for cam 3, fid 3060:
# Running inference for cam 3, fid 3065:
# Running inference for cam 3, fid 3070:
# Running inference for cam 3, fid 3075:
# Running inference for cam 3, fid 3080:
# Running inference for cam 3, fid 3085:
# Running inference for cam 3, fid 3090:
# Running inference for cam 3, fid 3095:
# Running inference for cam 3, fid 3100:
# Running inference for cam 3, fid 3105:
# Running inference for cam 3, fid 3110:
# Running inference for cam 3, fid 3115:
# Running inference for cam 3, fid 3120:
# Running inference for cam 3, fid 3125:
# Running inference for cam 3, fid 3130:
# Running inference for cam 3, fid 3135:
# Running inference for cam 3, fid 3140:
# Running inference for cam 3, fid 3145:
# Running inference for cam 3, fid 3150:
# Running inference for cam 3, fid 3155:
# Running inference for cam 3, fid 3160:
# Running inference for cam 3, fid 3165:
# Running inference for cam 3, fid 3170:
# Running inference for cam 3, fid 3175:
# Running inference for cam 3, fid 3180:
# Running inference for cam 3, fid 3185:
# Running inference for cam 3, fid 3190:
# Running inference for cam 3, fid 3195:
# Running inference for cam 3, fid 3200:
# Running inference for cam 3, fid 3205:
# Running inference for cam 3, fid 3210:
# Running inference for cam 3, fid 3215:
# Running inference for cam 3, fid 3220:
# Running inference for cam 3, fid 3225:
# Running inference for cam 3, fid 3230:
# Running inference for cam 3, fid 3235:
# Running inference for cam 3, fid 3240:
# Running inference for cam 3, fid 3245:
# Running inference for cam 3, fid 3250:
# Running inference for cam 3, fid 3255:
# Running inference for cam 3, fid 3260:
# Running inference for cam 3, fid 3265:
# Running inference for cam 3, fid 3270:
# Running inference for cam 3, fid 3275:
# Running inference for cam 3, fid 3280:
# Running inference for cam 3, fid 3285:
# Running inference for cam 3, fid 3290:
# Running inference for cam 3, fid 3295:
# Running inference for cam 3, fid 3300:
# Running inference for cam 3, fid 3305:
# Running inference for cam 3, fid 3310:
# Running inference for cam 3, fid 3315:
# Running inference for cam 3, fid 3320:
# Running inference for cam 3, fid 3325:
# Running inference for cam 3, fid 3330:
# Running inference for cam 3, fid 3335:
# Running inference for cam 3, fid 3340:
# Running inference for cam 3, fid 3345:
# Running inference for cam 3, fid 3350:
# Running inference for cam 3, fid 3355:
# Running inference for cam 3, fid 3360:
# Running inference for cam 3, fid 3365:
# Running inference for cam 3, fid 3370:
# Running inference for cam 3, fid 3375:
# Running inference for cam 3, fid 3380:
# Running inference for cam 3, fid 3385:
# Running inference for cam 3, fid 3390:
# Running inference for cam 3, fid 3395:
# Running inference for cam 3, fid 3400:
# Running inference for cam 3, fid 3405:
# Running inference for cam 3, fid 3410:
# Running inference for cam 3, fid 3415:
# Running inference for cam 3, fid 3420:
# Running inference for cam 3, fid 3425:
# Running inference for cam 3, fid 3430:
# Running inference for cam 3, fid 3435:
# Running inference for cam 3, fid 3440:
# Running inference for cam 3, fid 3445:
# Running inference for cam 3, fid 3450:
# Running inference for cam 3, fid 3455:
# Running inference for cam 3, fid 3460:
# Running inference for cam 3, fid 3465:
# Running inference for cam 3, fid 3470:
# Running inference for cam 3, fid 3475:
# Running inference for cam 3, fid 3480:
# Running inference for cam 3, fid 3485:
# Running inference for cam 3, fid 3490:
# Running inference for cam 3, fid 3495:
# Running inference for cam 3, fid 3500:
# Running inference for cam 3, fid 3505:
# Running inference for cam 3, fid 3510:
# Running inference for cam 3, fid 3515:
# Running inference for cam 3, fid 3520:
# Running inference for cam 3, fid 3525:
# Running inference for cam 3, fid 3530:
# Running inference for cam 3, fid 3535:
# Running inference for cam 3, fid 3540:
# Running inference for cam 3, fid 3545:
# Running inference for cam 3, fid 3550:
# Running inference for cam 3, fid 3555:
# Running inference for cam 3, fid 3560:
# Running inference for cam 3, fid 3565:
# Running inference for cam 3, fid 3570:
# Running inference for cam 3, fid 3575:
# Running inference for cam 3, fid 3580:
# Running inference for cam 3, fid 3585:
# Running inference for cam 3, fid 3590:
# Running inference for cam 3, fid 3595:
# Running inference for cam 3, fid 3600:
# Running inference for cam 3, fid 3605:
# Running inference for cam 3, fid 3610:
# Running inference for cam 3, fid 3615:
# Running inference for cam 3, fid 3620:
# Running inference for cam 3, fid 3625:
# Running inference for cam 3, fid 3630:
# Running inference for cam 3, fid 3635:
# Running inference for cam 3, fid 3640:
# Running inference for cam 3, fid 3645:
# Running inference for cam 3, fid 3650:
# Running inference for cam 3, fid 3655:
# Running inference for cam 3, fid 3660:
# Running inference for cam 3, fid 3665:
# Running inference for cam 3, fid 3670:
# Running inference for cam 3, fid 3675:
# Running inference for cam 3, fid 3680:
# Running inference for cam 3, fid 3685:
# Running inference for cam 3, fid 3690:
# Running inference for cam 3, fid 3695:
# Running inference for cam 3, fid 3700:
# Running inference for cam 3, fid 3705:
# Running inference for cam 3, fid 3710:
# Running inference for cam 3, fid 3715:
# Running inference for cam 3, fid 3720:
# Running inference for cam 3, fid 3725:
# Running inference for cam 3, fid 3730:
# Running inference for cam 3, fid 3735:
# Running inference for cam 3, fid 3740:
# Running inference for cam 3, fid 3745:
# Running inference for cam 3, fid 3750:
# Running inference for cam 3, fid 3755:
# Running inference for cam 3, fid 3760:
# Running inference for cam 3, fid 3765:
# Running inference for cam 3, fid 3770:
# Running inference for cam 3, fid 3775:
# Running inference for cam 3, fid 3780:
# Running inference for cam 3, fid 3785:
# Running inference for cam 3, fid 3790:
# Running inference for cam 3, fid 3795:
# Running inference for cam 3, fid 3800:
# Running inference for cam 3, fid 3805:
# Running inference for cam 3, fid 3810:
# Running inference for cam 3, fid 3815:
# Running inference for cam 3, fid 3820:
# Running inference for cam 3, fid 3825:
# Running inference for cam 3, fid 3830:
# Running inference for cam 3, fid 3835:
# Running inference for cam 3, fid 3840:
# Running inference for cam 3, fid 3845:
# Running inference for cam 3, fid 3850:
# Running inference for cam 3, fid 3855:
# Running inference for cam 3, fid 3860:
# Running inference for cam 3, fid 3865:
# Running inference for cam 3, fid 3870:
# Running inference for cam 3, fid 3875:
# Running inference for cam 3, fid 3880:
# Running inference for cam 3, fid 3885:
# Running inference for cam 3, fid 3890:
# Running inference for cam 3, fid 3895:
# Running inference for cam 3, fid 3900:
# Running inference for cam 3, fid 3905:
# Running inference for cam 3, fid 3910:
# Running inference for cam 3, fid 3915:
# Running inference for cam 3, fid 3920:
# Running inference for cam 3, fid 3925:
# Running inference for cam 3, fid 3930:
# Running inference for cam 3, fid 3935:
# Running inference for cam 3, fid 3940:
# Running inference for cam 3, fid 3945:
# Running inference for cam 3, fid 3950:
# Running inference for cam 3, fid 3955:
# Running inference for cam 3, fid 3960:
# Running inference for cam 3, fid 3965:
# Running inference for cam 3, fid 3970:
# Running inference for cam 3, fid 3975:
# Running inference for cam 3, fid 3980:
# Running inference for cam 3, fid 3985:
# Running inference for cam 3, fid 3990:
# Running inference for cam 3, fid 3995:
